# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BTP.csv')

# %%
df1 = df.drop('Subject', axis=1)

# %%
df2 = df1.drop('Hours taken to fall asleep', axis = 1)

# %%
df2.fillna(0, inplace=True)

# %%
df2.replace('         .', 0, inplace=True)

# %%
X = df2.iloc[:, :40]

# %%
X
# Out:
#      Irritability  \
# 0             2.0
# 1             0.0
# 2             0.0
# 3             3.0
# 4             2.0
# ..            ...
# 912           2.0
# 913           2.0
# 914           0.0
# 915           0.0
# 916           0.0
#
#      Increased unnecessary whole body movements in specific situations  \
# 0                                                  2.0
# 1                                                  0.0
# 2                                                  0.0
# 3                                                  2.0
# 4                                                  0.0
# ..                                                 ...
# 912                                                0.0
# 913                                                0.0
# 914                                                0.0
# 915                                                2.0
# 916                                                0.0
#
# ...

# %%
y = df2.iloc[:, 40]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 912    1
# 913    1
# 914    0
# 915    0
# 916    0
# Name: GAD, Length: 917, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
df2.corr()['GAD']
# Out:
# Irritability                                                                                   0.134861
# Increased unnecessary whole body movements in specific situations                              0.097303
# Difficulty concentrating on tasks or play activity independently                               0.094650
# Difficulty concentrating on adult-directed tasks or play activities                            0.100960
# Inattention                                                                                    0.107533
# Fear about possible harm befalling major attachment figures                                    0.169988
# Fear about calamitous separation                                                               0.105794
# Avoidance of being alone                                                                       0.233998
# Anticipatory distress/resistance to separation                                                 0.073999
# ...

# %%
df2
# Out:
#      Irritability  \
# 0             2.0
# 1             0.0
# 2             0.0
# 3             3.0
# 4             2.0
# ..            ...
# 912           2.0
# 913           2.0
# 914           0.0
# 915           0.0
# 916           0.0
#
#      Increased unnecessary whole body movements in specific situations  \
# 0                                                  2.0
# 1                                                  0.0
# 2                                                  0.0
# 3                                                  2.0
# 4                                                  0.0
# ..                                                 ...
# 912                                                0.0
# 913                                                0.0
# 914                                                0.0
# 915                                                2.0
# 916                                                0.0
#
# ...

# %%
from tensorflow import keras as k

# %%
classifier = k.Sequential()

# %%
classifier.add(k.layers.Dense(22,  activation='relu', input_dim=40))

# %%
classifier.add(k.layers.Dense(22,activation='relu'))

# %%
classifier.add(k.layers.Dense(1, activation='sigmoid'))

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf

# %%
X_train = np.asarray(X_train).astype(float)
X_test = np.asarray(X_test).astype(float)
y_train = np.asarray(y_train).astype(float)
y_test = np.asarray(y_test).astype(float)
X1 = X_train.astype(int)
y1 = y_train.astype(int)
X2 = X_test.astype(int)
y2 = y_test.astype(int)

# %%
classifier.fit(X1,y1,batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 0s 1ms/step - loss: 1.2086 - accuracy: 0.6856
# Epoch 2/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.6091 - accuracy: 0.7598
# Epoch 3/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.5720 - accuracy: 0.7525
# Epoch 4/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.5275 - accuracy: 0.7889
# Epoch 5/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4905 - accuracy: 0.7948
# Epoch 6/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4626 - accuracy: 0.8195
# Epoch 7/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4433 - accuracy: 0.8253
# Epoch 8/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4198 - accuracy: 0.8341
# Epoch 9/100
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8515
# Epoch 10/100
# ...

# %%
ypred = classifier.predict(X2)

# %%
ypred = ypred>0.65

# %%
ypred
# Out:
# array([[ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
# ...

# %%
y2 = y2>0

# %%
y2
# Out:
# array([ True,  True, False, False, False, False,  True, False,  True,
#        False, False, False, False, False, False, False, False,  True,
#         True,  True, False,  True, False, False,  True, False, False,
#        False, False, False, False,  True,  True, False, False, False,
#         True, False, False, False, False,  True, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False,  True, False,  True, False, False, False,
#        False, False, False,  True, False, False,  True,  True, False,
#        False, False,  True, False, False, False, False,  True,  True,
#        False,  True,  True, False, False, False,  True,  True,  True,
#        False, False,  True,  True, False, False, False,  True,  True,
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y2,ypred)

# %%
cm
# Out:
# array([[153,  10],
#        [ 41,  26]], dtype=int64)

# %%
# Out:
# 0.717391304347826
